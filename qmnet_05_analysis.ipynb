# %%
import qctoolkit as qtk
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
# hist_data = qtk.load('increment_test_hist.pkl')
hist_data = qtk.load('A2_deep_test_hist.pkl')
#hist_data = qtk.load('H2_deep_test_hist.pkl')

# %%
plt.loglog(hist_data[0])
plt.loglog(hist_data[1])
plt.loglog(hist_data[2])
plt.loglog(hist_data[-1])
